# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6]
y=[124,45,56,34,78,90]

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
import matplotlib.pyplot as plt

# Example data
companies = ["Company A", "Company B", "Company C"]
values = [150, 200, 120]

# Create a bar plot
plt.bar(companies, values, color='blue')

# %%
import matplotlib.pyplot as plt

# Example data
companies = ["Company A", "Company B", "Company C"]
values = [150, 200, 120]
profits=[123,456,675]

plt.bar(range(len(companies)),values)
plt.bar(profits,companies)
# Out:
# <BarContainer object of 3 artists>

# %%
x=[1,2,3,4,5,6,7]
y=[50,34,56,23,56,78,90]

# %%
plt.xlabel('Time')
plt.ylabel('Distance')
plt.grid()
plt.title('Sarinodu maa hero')
plt.plot(x,y, 'gD--', alpha=0.4, label='cinema chupisthaa mawa')
plt.legend()
