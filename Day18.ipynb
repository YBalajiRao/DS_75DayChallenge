# %%
import cv2
import os

# %%
image=cv2.imread(r"C:\Users\91944\Desktop\75 Days hard CODING challenge\images_dataset\Tomato___healthy\0a0d6a11-ddd6-4dac-8469-d5f65af5afca___RS_HL 0555_newPixel25.JPG")

# %%
resized_image = cv2.resize(image, (0, 0), fx=0.5, fy=0.5)

# Save the resized image
cv2.imwrite("resized_image.jpg", resized_image)
# Out:
# True

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
image=cv2.imread(r"C:\Users\91944\Desktop\75 Days hard CODING challenge\images_dataset\Tomato___healthy\0a0d6a11-ddd6-4dac-8469-d5f65af5afca___RS_HL 0555_newPixel25.JPG")
# Convert the image from BGR to RGB (OpenCV uses BGR by default)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(image_rgb)
plt.axis('off')  # Hide axes
plt.show()

# %%
import cv2
from IPython.display import display, Image

# Read the image
image = cv2.imread("resized_image.jpg")  # Change the path to your image file

# Convert the image from BGR to RGB (OpenCV uses BGR by default)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image using IPython.display.Image
display(Image(data=cv2.imencode('.png', image_rgb)[1]))
